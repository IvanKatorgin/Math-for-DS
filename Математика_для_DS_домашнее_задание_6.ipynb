# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanKatorgin/math-for-DS/blob/main/%D0%9C%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D0%BA%D0%B0_%D0%B4%D0%BB%D1%8F_DS_%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Курс "Математика для Data Science". Домашнее задание 6. Центральная предельная теорема и статистика. Каторгин И.П.

# %% [markdown]
# Задание

# %% [markdown]
# В этом задании нужно убедиться, что ЦПТ действительно работает.
#
# Создайте случайную величину из [любого выбранного вами распределения](https://docs.scipy.org/doc/scipy/reference/stats.html), для разных значений `n` сгенерируйте 1000 выборок размера `n`. Постройте гистрограммы средних этих выборок и сделайте выводы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %%
rv = sts.uniform()  # Выбираем распределение (равномерное)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
n1 = 2                # Размеры выборок
n2 = 5
n3 = 10
n4 = 30

a1 = np.array([])     # Массивы для сохранения средних по выборкам
a2 = np.array([])
a3 = np.array([])
a4 = np.array([])

samples_count = 1000  # Количество повторов генерации

for number in range(samples_count):
    sample1 = rv.rvs(size=n1)               # На каждом цикле генерируем выборки указанных размеров
    sample2 = rv.rvs(size=n2)
    sample3 = rv.rvs(size=n3)
    sample4 = rv.rvs(size=n4)
    a1 = np.append(a1, sample1.mean())      # Считаем среднее по каждой выборке и добавляем в массив средних
    a2 = np.append(a2, sample2.mean())
    a3 = np.append(a3, sample3.mean())
    a4 = np.append(a4, sample4.mean())

# %%
label_1 = 'sample of ' + str(n1) + ' histogram'   # Подписи для графиков
label_2 = 'sample of ' + str(n2) + ' histogram'
label_3 = 'sample of ' + str(n3) + ' histogram'
label_4 = 'sample of ' + str(n4) + ' histogram'
plt.hist(a1, density=True, label=label_1)         # Строим графики
plt.hist(a2, density=True, label=label_2)
plt.hist(a3, density=True, label=label_3)
plt.hist(a4, density=True, label=label_4)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
rv = sts.lognorm(s=1)  # Выбираем распределение (логнормальное)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
n1 = 200               # Размеры выборок
n2 = 500
n3 = 1000
n4 = 3000

a1 = np.array([])     # Массивы для сохранения средних по выборкам
a2 = np.array([])
a3 = np.array([])
a4 = np.array([])

samples_count = 1000  # Количество повторов генерации

for number in range(samples_count):
    sample1 = rv.rvs(size=n1)               # На каждом цикле генерируем выборки указанных размеров
    sample2 = rv.rvs(size=n2)
    sample3 = rv.rvs(size=n3)
    sample4 = rv.rvs(size=n4)
    a1 = np.append(a1, sample1.mean())      # Считаем среднее по каждой выборке и добавляем в массив средних
    a2 = np.append(a2, sample2.mean())
    a3 = np.append(a3, sample3.mean())
    a4 = np.append(a4, sample4.mean())

# %%
label_1 = 'sample of ' + str(n1) + ' histogram'   # Подписи для графиков
label_2 = 'sample of ' + str(n2) + ' histogram'
label_3 = 'sample of ' + str(n3) + ' histogram'
label_4 = 'sample of ' + str(n4) + ' histogram'
plt.hist(a1, density=True, label=label_1)         # Строим графики
plt.hist(a2, density=True, label=label_2)
plt.hist(a3, density=True, label=label_3)
plt.hist(a4, density=True, label=label_4)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
rv = sts.gamma(a=2, scale=1)  # Выбираем распределение (гамма распределение)
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
n1 = 20               # Размеры выборок
n2 = 50
n3 = 100
n4 = 300

a1 = np.array([])     # Массивы для сохранения средних по выборкам
a2 = np.array([])
a3 = np.array([])
a4 = np.array([])

samples_count = 1000  # Количество повторов генерации

for number in range(samples_count):
    sample1 = rv.rvs(size=n1)               # На каждом цикле генерируем выборки указанных размеров
    sample2 = rv.rvs(size=n2)
    sample3 = rv.rvs(size=n3)
    sample4 = rv.rvs(size=n4)
    a1 = np.append(a1, sample1.mean())      # Считаем среднее по каждой выборке и добавляем в массив средних
    a2 = np.append(a2, sample2.mean())
    a3 = np.append(a3, sample3.mean())
    a4 = np.append(a4, sample4.mean())

# %%
label_1 = 'sample of ' + str(n1) + ' histogram'   # Подписи для графиков
label_2 = 'sample of ' + str(n2) + ' histogram'
label_3 = 'sample of ' + str(n3) + ' histogram'
label_4 = 'sample of ' + str(n4) + ' histogram'
plt.hist(a1, density=True, label=label_1)         # Строим графики
plt.hist(a2, density=True, label=label_2)
plt.hist(a3, density=True, label=label_3)
plt.hist(a4, density=True, label=label_4)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# Основные выводы:
# 1. На различных распределениях (равномерное, логнормальное и гамма распределение) была доказана ЦПТ.
# 2. Размер выборок влияет на параметры нового распределения (стандартного), а именно на сигму и параметры среднего (samples means). Так, чем больше размер выборки, тем сигма становится меньше, а само распределение становится как-бы "уже" (более узким), а параметры среднего (samples means) становятся больше.
