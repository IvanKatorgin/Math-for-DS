# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanKatorgin/math-for-DS/blob/main/%D0%94%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D0%B5_%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание "Функции нескольких переменных".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте частные производные функций:
#
# 1) $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# 2) $f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y$

# %%
### YOUR CODE HERE

# %%
import numpy as np
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt
from sympy import *

# %matplotlib inline

# %%
# функция 1

# %%
x, y = symbols('x y')

# %%
diff(2*x**2*y**3 + 1/x + y**2*x + 7, x)
# Out:
# 4*x*y**3 + y**2 - 1/x**2

# %%
diff(2*x**2*y**3 + 1/x + y**2*x + 7, y)
# Out:
# 6*x**2*y**2 + 2*x*y

# %%
# функция 2

# %%
diff(x**2*y - sin(x*y) + cos(x**2) + 6*y, x)
# Out:
# 2*x*y - 2*x*sin(x**2) - y*cos(x*y)

# %%
diff(x**2*y - sin(x*y) + cos(x**2) + 6*y, y)
# Out:
# x**2 - x*cos(x*y) + 6

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Вычислите градиент функции:
#
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$
#
# в точке $(1,2)$

# %%
### YOUR CODE HERE

# %%
pip install numdifftools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import numdifftools as nd

def f(x):
    return 2*x[0]**2*x[1]**3 + 1/x[0] + x[1]**2*x[0] + 7

grad = nd.Gradient(f)([1, 2])
print(grad)
# Out:
# [35. 28.]

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Постройте трехмерный график функции
#
# $f(x)=x_2^2-x_1^2 x_2 + 2 x_1 x_2$

# %%
### YOUR CODE HERE

# %%
from numpy import arange
from numpy import meshgrid
from mpl_toolkits.mplot3d import Axes3D
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy import meshgrid

# %%
x1 = np.linspace(-5, 5, 1000)

# %%
x2 = np.linspace(-5, 5, 1000)

# %%
y = x2**2 - x1**2*x2 + 2*x1*x2

# %%
fig = plt.figure()

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining all 3 axis
z = y
x = x1
y = x2

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot geeks for geeks')
plt.show()

# %%
def f(x):
  return x2**2 - x1**2*x2 + 2*x1*x2

x1 = np.linspace(-5, 5, 1000)
x2 = np.linspace(-5, 5, 1000)
result = (f(x))

fig = plt.figure()

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining all 3 axis
z = result
x = x1
y = x2

# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot geeks for geeks')
plt.show()
